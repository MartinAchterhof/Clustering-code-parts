# %% [markdown]
# # Start Colab and the Google Drive environment

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/"
# Out:
#  AchterhofMartin_u760301_Revision:Introduction_Individual_assignment.docx.gdoc
#  Achterhof_RK.docx
#  Achterhof_RK.docx.gdoc
# 'Answers Methodology exam prep.gdoc'
# 'Assignment 5 Law.gdoc'
# 'Assignment answers.gsheet'
# 'Characterizing the Real Estate Market Video.mp4'
# 'Colab Notebooks'
# 'Criteria Research paper.docx'
# 'Dates overview.pdf'
# "Domains of Smart City's.gdoc"
#  DSBG_14_abstract_RK.docx
#  DSBG_14_abstract_RK.docx.gdoc
# 'DSBG_14_RK (1).docx'
# 'DSBG_14_RK (1).docx.gdoc'
# 'DSBG14_RK (1).docx.gdoc'
# 'DSBG_14_RK (2).docx.gdoc'
# 'DSBG14_RK (2).docx.gdoc'
#  DSBG_14_RK.docx
#  DSBG14_RK.docx
#  DSBG_14_RK.docx.gdoc
#  DSBG14_RK.docx.gdoc
#  Eindcijfer.gsheet
# 'Feature description.gsheet'
# 'Hyperparameters .gsheet'
# 'Hyperparameters & silhouette score.gsheet'
# 'Introduction Resit.docx'
# 'JAAP dataset.gsheet'
# 'Keuzevakken + ects.gsheet'
#  Law
# 'Law assignment 3.gdoc'
# 'Lieve Elisa, .gdoc'
# 'Master Data Science & Society'
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import pyplot
from sklearn import preprocessing
import numpy as n
import matplotlib.pyplot as m
import pandas as p
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import feature_selection
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from copy import deepcopy
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn import metrics
from sklearn.cluster import DBSCAN

# %%
# !pip install -q keras

# %% [markdown]
# # Upload the 4 cities for the evaluation scores

# %%
# !python3 "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Amsterdam_excl_cluster.csv"
# !python3 "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Rotterdam_excl_cluster.csv"
# !python3 "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Utrecht_excl_cluster.csv"
# !python3 "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/DenHaag_excl_cluster.csv"
# Out:
#   File "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Amsterdam_excl_cluster.csv", line 1
#     ,ObjectId,CurrentPrice,Woonoppervlakte,Inhoud,Perceeloppervlakte,Kamers,Slaapkamers,Balkon,Garage,DaysOnline,ObjectType_Appartement,ObjectType_Herenhuis,ObjectType_Tussenwoning,ObjectType_Villa,ObjectType_Vrijstaande woning,ObjectType_Woonboerderij,Tuin_-,Tuin_Ja
#     ^
# SyntaxError: invalid syntax
#   File "/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Rotterdam_excl_cluster.csv", line 1
#     ,ObjectId,CurrentPrice,Woonoppervlakte,Inhoud,Perceeloppervlakte,Kamers,Slaapkamers,Balkon,Garage,DaysOnline,ObjectType_Appartement,ObjectType_Herenhuis,ObjectType_Tussenwoning,ObjectType_Villa,ObjectType_Vrijstaande woning,ObjectType_Woonboerderij,Tuin_-,Tuin_Ja
#     ^
# SyntaxError: invalid syntax
# ...

# %%
import pandas as pd

df_amsterdam = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Amsterdam_excl_cluster.csv", encoding = "ISO-8859-1")
df_amsterdam = df_amsterdam.drop(df_amsterdam.columns[0], axis=1)
df_rotterdam = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Rotterdam_excl_cluster.csv", encoding = "ISO-8859-1")
df_rotterdam = df_rotterdam.drop(df_rotterdam.columns[0], axis=1)
df_utrecht = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/Utrecht_excl_cluster.csv", encoding = "ISO-8859-1")
df_utrecht = df_utrecht.drop(df_utrecht.columns[0], axis=1)
df_denhaag = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities/DenHaag_excl_cluster.csv", encoding = "ISO-8859-1")
df_denhaag = df_denhaag.drop(df_denhaag.columns[0], axis=1)

# %%
df_amsterdam_exclId = df_amsterdam.drop(df_amsterdam.columns[0], axis=1)
df_ex_city = df_amsterdam_exclId

scaler=StandardScaler()#instantiate
scaler.fit(df_ex_city) # compute the mean and standard which will be used in the next command
X_scaled=scaler.transform(df_ex_city)

pca=PCA(n_components=12) 
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 
#let's check the shape of X_pca array
print ("shape of X_pca", X_pca.shape)


amsterdam_2d = X_pca

################################################################################################
df_rotterdam_exclId = df_rotterdam.drop(df_rotterdam.columns[0], axis=1)
df_ex_city = df_rotterdam_exclId

scaler=StandardScaler()#instantiate
scaler.fit(df_ex_city) # compute the mean and standard which will be used in the next command
X_scaled=scaler.transform(df_ex_city)

pca=PCA(n_components=12) 
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 
#let's check the shape of X_pca array
print ("shape of X_pca", X_pca.shape)


rotterdam_2d = X_pca

################################################################################################
df_utrecht_exclId = df_utrecht.drop(df_utrecht.columns[0], axis=1)
df_ex_city = df_utrecht_exclId

scaler=StandardScaler()#instantiate
scaler.fit(df_ex_city) # compute the mean and standard which will be used in the next command
X_scaled=scaler.transform(df_ex_city)

pca=PCA(n_components=12) 
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 
#let's check the shape of X_pca array
print ("shape of X_pca", X_pca.shape)


utrecht_2d = X_pca

################################################################################################
df_denhaag_exclId = df_denhaag.drop(df_denhaag.columns[0], axis=1)
df_ex_city = df_denhaag_exclId

scaler=StandardScaler()#instantiate
scaler.fit(df_ex_city) # compute the mean and standard which will be used in the next command
X_scaled=scaler.transform(df_ex_city)

pca=PCA(n_components=12) 
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 
#let's check the shape of X_pca array
print ("shape of X_pca", X_pca.shape)


denhaag_2d = X_pca
# Out:
# shape of X_pca (5512, 12)
# shape of X_pca (3845, 12)
# shape of X_pca (1726, 12)
# shape of X_pca (3286, 12)

# %% [markdown]
# # Installing packages

# %% [markdown]
# # AMSTERDAM

# %% [markdown]
# ## Silhouete score + *k*-means | Amsterdam

# %%
X = amsterdam_2d

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.2580742131548821
# For n_clusters = 3 The average silhouette_score is : 0.21912934108637036
# For n_clusters = 4 The average silhouette_score is : 0.22233048990935508
# For n_clusters = 5 The average silhouette_score is : 0.22369284990356708
# For n_clusters = 6 The average silhouette_score is : 0.25647833413988114

# %%
number_of_clusters = 2
X = amsterdam_2d

# Using scikit-learn to perform K-Means clustering
    
# Specify the number of clusters (x) and fit the data X
kmeans = KMeans(n_clusters= number_of_clusters, random_state=0).fit(X)

# Get the cluster centroids
print(kmeans.cluster_centers_)
    
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[-1.19112896e+00  6.13242379e-02  8.15007271e-03  4.26327337e-02
#    6.36647379e-02  2.26698559e-02  2.35555804e-02 -5.63443605e-02
#    5.91384780e-03 -3.49715366e-02 -1.64314806e-02  9.81201813e-04]
#  [ 2.28268205e+00 -1.17521899e-01 -1.56188166e-02 -8.17014611e-02
#   -1.22007239e-01 -4.34445598e-02 -4.51419641e-02  1.07978452e-01
#   -1.13333104e-02  6.70195268e-02  3.14893243e-02 -1.88037723e-03]]
# [1 1 0 ... 1 0 0]

# %%
X = amsterdam_2d

clusters = kmeans.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_amsterdam['cluster'] = clusters

df_amsterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/amsterdam_kmeans_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## Wald + Agglomerative clustering | Amsterdam

# %%
X = amsterdam_2d

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.metrics import silhouette_score 
import scipy.cluster.hierarchy as shc 

plt.figure(figsize =(8, 8)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
X = amsterdam_2d
number_of_clusters = 2

from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=number_of_clusters, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)

score=metrics.silhouette_score(np.array(X),cluster.labels_,metric='euclidean') 

print(score)
# Out:
# 0.26337073186710025

# %%
X = amsterdam_2d

clusters = cluster.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
#plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_amsterdam['cluster'] = clusters

df_amsterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/amsterdam_agglomerative_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## DBSCAN | Amsterdam

# %%
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

X = amsterdam_2d
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X)
distances, indices = nbrs.kneighbors(X)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.title("Epsilon determination Amsterdam")
plt.plot(distances)

# %%
X = amsterdam_2d

# Compute DBSCAN
db = DBSCAN(eps=1.67, min_samples=84).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.5f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=4)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=3)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 8
# Estimated number of noise points: 1338
# Silhouette Coefficient: 0.10799

# %%
df_amsterdam['cluster'] = labels

df_amsterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/amsterdam_DBSCAN_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # ROTTERDAM

# %% [markdown]
# ## Silhouete score + *k*-means | Rotterdam

# %%
X = rotterdam_2d

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.31831354636691683
# For n_clusters = 3 The average silhouette_score is : 0.26194311737540044
# For n_clusters = 4 The average silhouette_score is : 0.26920219127846323
# For n_clusters = 5 The average silhouette_score is : 0.27530553539939423
# For n_clusters = 6 The average silhouette_score is : 0.26657617773810766

# %%
number_of_clusters = 6
X = rotterdam_2d

# Using scikit-learn to perform K-Means clustering
    
# Specify the number of clusters (x) and fit the data X
kmeans = KMeans(n_clusters= number_of_clusters, random_state=0).fit(X)

# Get the cluster centroids
print(kmeans.cluster_centers_)
    
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[ 2.60612953e+00 -1.91673419e+00 -7.48098529e-01  3.47935059e-01
#   -6.73512595e-01 -7.35365014e-01 -3.69223104e-01 -1.14179851e-01
#    1.20234355e+00  8.71722459e-01  1.23450307e-02 -2.39247839e-01]
#  [ 4.28989587e-01 -1.42641472e+00  5.65191180e-01 -6.21679171e-02
#    3.56557178e-01  2.75770952e-01 -9.21752705e-02  3.21965684e-01
#   -7.72692909e-01 -3.01197612e-01  1.50730079e-01 -2.82380281e-02]
#  [-1.56645018e+00  5.66311791e-01 -1.71965889e-01  2.14785714e-02
#   -7.47762707e-02 -6.08634037e-02  5.89963543e-02 -1.10213151e-01
#    1.19717322e-01 -1.88480536e-02 -7.12729078e-02  4.12066605e-02]
#  [ 4.99474287e+00  3.23337411e+00  3.57949886e+00  6.98113359e+00
#   -4.16460902e+00  6.47306638e+00  2.83044675e-01 -1.59852370e-01
#    3.40750194e-01  2.89585889e-01  4.83087471e-02 -1.87899865e+00]
#  [ 4.40979077e+00  1.74259058e+00  3.44437981e+00 -4.84958457e+00
#   -1.61225108e+00  1.07229852e-01  3.02151722e+00 -2.65921995e-01
# ...

# %%
X = rotterdam_2d

clusters = kmeans.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_rotterdam['cluster'] = clusters

df_rotterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/rotterdam_kmeans_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## Wald + Agglomerative clustering | Rotterdam

# %%
X = rotterdam_2d

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.metrics import silhouette_score 
import scipy.cluster.hierarchy as shc 

plt.figure(figsize =(8, 8)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
X = rotterdam_2d
number_of_clusters = 6

from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=number_of_clusters, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)


score=metrics.silhouette_score(np.array(X),cluster.labels_,metric='euclidean')  #   euclidean  ??

print(score)
# Out:
# 0.2669690807025082

# %%
X = rotterdam_2d

clusters = cluster.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
#plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_rotterdam['cluster'] = clusters

df_rotterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/rotterdam_agglomerative_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## DBSCAN | Rotterdam

# %%
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

X = rotterdam_2d
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X)
distances, indices = nbrs.kneighbors(X)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.title("Epsilon determination Rotterdam")
plt.plot(distances)

# %%
X = rotterdam_2d

# Compute DBSCAN
db = DBSCAN(eps=1.67, min_samples=50).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.5f"
      % metrics.silhouette_score(X, labels))


# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=4)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=3)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 10
# Estimated number of noise points: 886
# Silhouette Coefficient: 0.16903

# %%
df_rotterdam['cluster'] = labels

df_rotterdam.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/rotterdam_DBSCAN_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # UTRECHT

# %% [markdown]
# ## Silhouete score + *k*-means | Utrecht

# %%
X = utrecht_2d

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.24641207791120487
# For n_clusters = 3 The average silhouette_score is : 0.2203972324280021
# For n_clusters = 4 The average silhouette_score is : 0.22771492211164693
# For n_clusters = 5 The average silhouette_score is : 0.2318451887168381
# For n_clusters = 6 The average silhouette_score is : 0.2471979205949358

# %%
number_of_clusters = 6
X = utrecht_2d

# Using scikit-learn to perform K-Means clustering
    
# Specify the number of clusters (x) and fit the data X
kmeans = KMeans(n_clusters= number_of_clusters, random_state=0).fit(X)

# Get the cluster centroids
print(kmeans.cluster_centers_)
    
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[ 3.55440310e+00  2.24487228e+00  3.09928302e-01 -3.92887463e+00
#    1.18456392e+00 -4.35591230e-01  2.62743597e+00  2.30465488e-01
#    5.73720624e-01  1.43136020e+00  2.78231509e-01 -5.05790824e-01]
#  [-2.57282649e-01 -1.37324132e+00  1.58612274e-01 -1.48471370e-01
#   -1.52837926e-02  7.79573927e-02  2.72754367e-01 -1.01575273e-01
#    1.66030930e-01 -2.97206572e-01 -8.48486884e-02  1.26949513e-02]
#  [-2.11358540e+00  1.12407427e+00 -2.02426923e-01  1.27596698e-01
#    4.28426044e-02 -1.36189191e-02 -2.07809559e-01  1.06604570e-01
#   -2.33557741e-01  1.87895443e-01  3.97993658e-02  5.93055120e-02]
#  [ 2.40841909e+00  1.09482523e-03  3.03099967e+00 -1.97720973e-01
#   -5.36016011e+00 -4.06332905e+00 -1.60915473e+00  2.20193408e+00
#    6.01166190e-01  1.34247279e+00 -5.11922918e-01 -4.54802687e-01]
#  [ 3.01235870e+00  3.33868305e+00  1.11553947e+01  1.14973120e+01
#    1.23179962e+01 -3.66736444e+00  4.58014052e+00  1.05907937e+01
# ...

# %%
X = utrecht_2d

clusters = kmeans.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_utrecht['cluster'] = clusters

df_utrecht.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/utrecht_kmeans_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## Wald + Agglomerative clustering | Utrecht

# %%
X = utrecht_2d

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.metrics import silhouette_score 
import scipy.cluster.hierarchy as shc 

plt.figure(figsize =(8, 8)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
X = utrecht_2d
number_of_clusters = 6

from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=number_of_clusters, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)


score=metrics.silhouette_score(np.array(X),cluster.labels_,metric='euclidean')  #   euclidean  ??

print(score)
# Out:
# 0.2763004283699456

# %%
X = utrecht_2d

clusters = cluster.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
#plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_utrecht['cluster'] = clusters

df_utrecht.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/utrecht_agglomerative_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## DBSCAN | Utrecht

# %%
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

X = utrecht_2d
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X)
distances, indices = nbrs.kneighbors(X)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.title("Epsilon determination Utrecht")
plt.plot(distances)

# %%
X = utrecht_2d

# Compute DBSCAN
db = DBSCAN(eps=1.55, min_samples=35).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.5f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=4)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=3)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 8
# Estimated number of noise points: 548
# Silhouette Coefficient: 0.11713

# %%
df_utrecht['cluster'] = labels

df_utrecht.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/utrecht_DBSCAN_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # DEN HAAG

# %% [markdown]
# ## Silhouete score + *k*-means | Den Haag

# %%
X = denhaag_2d

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.26764951930499287
# For n_clusters = 3 The average silhouette_score is : 0.22424296122971699
# For n_clusters = 4 The average silhouette_score is : 0.23080628565766484
# For n_clusters = 5 The average silhouette_score is : 0.24852271589191716
# For n_clusters = 6 The average silhouette_score is : 0.24784125439807483

# %%
number_of_clusters = 3
X = denhaag_2d

# Using scikit-learn to perform K-Means clustering
    
# Specify the number of clusters (x) and fit the data X
kmeans = KMeans(n_clusters= number_of_clusters, random_state=0).fit(X)

# Get the cluster centroids
print(kmeans.cluster_centers_)
    
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[ 0.62596541 -1.60670043]
#  [-1.65113897  0.67122718]
#  [ 3.47680255  0.82331972]]
# [2 1 0 ... 0 2 1]

# %%
X = denhaag_2d

clusters = kmeans.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_denhaag['cluster'] = clusters

df_denhaag.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/denhaag_kmeans_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## Wald + Agglomerative clustering | Den Haag

# %%
X = denhaag_2d

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.metrics import silhouette_score 
import scipy.cluster.hierarchy as shc 

plt.figure(figsize =(8, 8)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
X = denhaag_2d
number_of_clusters = 16

from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=number_of_clusters, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)


score=metrics.silhouette_score(np.array(X),cluster.labels_,metric='euclidean')  #   euclidean  ??

print(score)
# Out:
# 0.2140218032153039

# %%
X = denhaag_2d

clusters = cluster.labels_

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], s=10, c=clusters, cmap="plasma")
#plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], c='red', marker='*', s=250)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_denhaag['cluster'] = clusters

df_denhaag.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/denhaag_agglomerative_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## DBSCAN | Den Haag

# %%
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

X = denhaag_2d
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X)
distances, indices = nbrs.kneighbors(X)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.title("Epsilon determination the Hague")
plt.plot(distances)

# %%
X = denhaag_2d

# Compute DBSCAN
db = DBSCAN(eps=1.4, min_samples=50).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.5f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=4)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=3)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 6
# Estimated number of noise points: 1234
# Silhouette Coefficient: 0.10298

# %%
df_denhaag['cluster'] = labels

df_denhaag.to_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/denhaag_DBSCAN_labels.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # More evaluation methods

# %%
## kmeans datasets
df_amsterdam_labels_kmean = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/amsterdam_kmeans_labels.csv", encoding = "ISO-8859-1")
df_amsterdam_labels_kmean = df_amsterdam_labels_kmean.drop(df_amsterdam.columns[0], axis=1)
df_rotterdam_labels_kmean = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/rotterdam_kmeans_labels.csv", encoding = "ISO-8859-1")
df_rotterdam_labels_kmean = df_rotterdam_labels_kmean.drop(df_rotterdam.columns[0], axis=1)
df_utrecht_labels_kmean = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/utrecht_kmeans_labels.csv", encoding = "ISO-8859-1")
df_utrecht_labels_kmean = df_utrecht_labels_kmean.drop(df_utrecht.columns[0], axis=1)
df_denhaag_labels_kmean = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/kmeans/denhaag_kmeans_labels.csv", encoding = "ISO-8859-1")
df_denhaag_labels_kmean = df_denhaag_labels_kmean.drop(df_denhaag.columns[0], axis=1)

## agglomerative datasets
df_amsterdam_labels_agglomerative = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/amsterdam_agglomerative_labels.csv", encoding = "ISO-8859-1")
df_amsterdam_labels_agglomerative = df_amsterdam_labels_agglomerative.drop(df_amsterdam.columns[0], axis=1)
df_rotterdam_labels_agglomerative = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/rotterdam_agglomerative_labels.csv", encoding = "ISO-8859-1")
df_rotterdam_labels_agglomerative = df_rotterdam_labels_agglomerative.drop(df_rotterdam.columns[0], axis=1)
df_utrecht_labels_agglomerative = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/utrecht_agglomerative_labels.csv", encoding = "ISO-8859-1")
df_utrecht_labels_agglomerative = df_utrecht_labels_agglomerative.drop(df_utrecht.columns[0], axis=1)
df_denhaag_labels_agglomerative = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/Agglomerative/denhaag_agglomerative_labels.csv", encoding = "ISO-8859-1")
df_denhaag_labels_agglomerative = df_denhaag_labels_agglomerative.drop(df_denhaag.columns[0], axis=1)

## DBSCAN datasets
df_amsterdam_labels_DBSCAN = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/amsterdam_DBSCAN_labels.csv", encoding = "ISO-8859-1")
df_amsterdam_labels_DBSCAN = df_amsterdam_labels_DBSCAN.drop(df_amsterdam.columns[0], axis=1)
df_rotterdam_labels_DBSCAN = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/rotterdam_DBSCAN_labels.csv", encoding = "ISO-8859-1")
df_rotterdam_labels_DBSCAN = df_rotterdam_labels_DBSCAN.drop(df_rotterdam.columns[0], axis=1)
df_utrecht_labels_DBSCAN = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/utrecht_DBSCAN_labels.csv", encoding = "ISO-8859-1")
df_utrecht_labels_DBSCAN = df_utrecht_labels_DBSCAN.drop(df_utrecht.columns[0], axis=1)
df_denhaag_labels_DBSCAN = pd.read_csv("/content/drive/My Drive/Master Data Science & Society/Year 2/Thesis/Data/df_cities_labels/DBSCAN/denhaag_DBSCAN_labels.csv", encoding = "ISO-8859-1")
df_denhaag_labels_DBSCAN = df_denhaag_labels_DBSCAN.drop(df_denhaag.columns[0], axis=1)

# %% [markdown]
# ## Create train and test set for calculating the evaluation scores

# %%
X = amsterdam_2d

## Kmeans

number_of_clusters = 2

# Using scikit-learn to perform K-Means clustering
    
# Specify the number of clusters (x) and fit the data X
kmeans = KMeans(n_clusters= number_of_clusters, random_state=0).fit(X)

predicted_clusters = kmeans.labels_

# %%
predicted_clusters
# Out:
# array([1, 1, 0, ..., 1, 0, 0], dtype=int32)

# %%
actual_clusters = df_amsterdam_labels_kmean['cluster']

# %%
actual_clusters.to_numpy()
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %% [markdown]
# ## Normalized mutual information score

# %%
from sklearn import metrics

metrics.adjusted_mutual_info_score(actual_clusters, predicted_clusters)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 1.0

# %% [markdown]
# ## Davies buildin score

# %% [markdown]
# # Silhouette

# %%
n_clusters = 2
clusterer = KMeans(n_clusters=n_clusters, random_state=10)

X = utrecht_2d
cluster_labels = clusterer.fit_predict(X)
silhouette_avg = silhouette_score(X, cluster_labels)
silhouette_avg
# Out:
# 0.24641207791120487

# %%
metrics.adjusted_mutual_info_score(actual_clusters, predicted_clusters, average_method='arithmetic')
# Out:
# 1.0
